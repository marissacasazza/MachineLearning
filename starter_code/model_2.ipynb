# %%
# # Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade

# %%
# # install joblib. This will be used to save your model. 
# # Restart your kernel after installing 
# !pip install joblib

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
X = df.drop(columns=['koi_disposition'])

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
y = df['koi_disposition']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 6122              0              0              0              0    6.768901
# 6370              0              1              0              1    0.733726
# 2879              1              0              0              0    7.652707
# 107               0              0              0              0    7.953547
# 29                0              0              0              0    4.959319
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 6122     7.380000e-05    -7.380000e-05   133.077240          0.008440
# 6370     6.060000e-06    -6.060000e-06   132.020050          0.007950
# 2879     6.540000e-05    -6.540000e-05   134.460380          0.006190
# 107      1.910000e-05    -1.910000e-05   174.662240          0.001820
# 29       5.150000e-07    -5.150000e-07   172.258529          0.000083
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 6122         -0.008440  ...            -171      4.327           0.153
# 6370         -0.007950  ...            -175      4.578           0.033
# 2879         -0.006190  ...            -189      4.481           0.050
# 107          -0.001820  ...             -85      4.536           0.056
# 29           -0.000083  ...             -77      4.359           0.110
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 6122          -0.187     1.125          0.310         -0.207  294.40472
# 6370          -0.187     0.797          0.211         -0.056  284.50391
# 2879          -0.200     0.963          0.290         -0.097  295.50211
# 107           -0.016     0.779          0.023         -0.049  291.15878
# 29            -0.110     1.082          0.173         -0.130  292.16705
#
#             dec  koi_kepmag
# 6122  39.351681      14.725
# 6370  42.463860      15.770
# 2879  38.983540      13.099
# 107   40.750271      15.660
# 29    48.727589      15.263
#
# [5 rows x 40 columns]

# %% [markdown]
# # Pre-processing

# %%
# Scale your data
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)

# %%
rf
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %% [markdown]
# # Train the Model

# %%
print(f"Training Data Score: {rf.score(X_train, y_train)}")
print(f"Testing Data Score: {rf.score(X_test, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.8993135011441648

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'min_samples_leaf': [1,3,5,7],
              'min_weight_fraction_leaf': [0.0, 0.01],
              'n_estimators': [200, 100, 1, 400]}
grid = GridSearchCV(rf, param_grid, verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# [CV] min_samples_leaf=1, min_weight_fraction_leaf=0.0, n_estimators=200
# C:\Users\Marissa Laptop\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  min_samples_leaf=1, min_weight_fraction_leaf=0.0, n_estimators=200, score=0.905, total=   5.5s
# [CV] min_samples_leaf=1, min_weight_fraction_leaf=0.0, n_estimators=200
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    5.4s remaining:    0.0s
# [CV]  min_samples_leaf=1, min_weight_fraction_leaf=0.0, n_estimators=200, score=0.891, total=   5.2s
# [CV] min_samples_leaf=1, min_weight_fraction_leaf=0.0, n_estimators=200
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   10.6s remaining:    0.0s
# [CV]  min_samples_leaf=1, min_weight_fraction_leaf=0.0, n_estimators=200, score=0.880, total=   5.2s
# [CV] min_samples_leaf=1, min_weight_fraction_leaf=0.0, n_estimators=100
# [CV]  min_samples_leaf=1, min_weight_fraction_leaf=0.0, n_estimators=100, score=0.897, total=   2.6s
# [CV] min_samples_leaf=1, min_weight_fraction_leaf=0.0, n_estimators=100
# [CV]  min_samples_leaf=1, min_weight_fraction_leaf=0.0, n_estimators=100, score=0.884, total=   2.7s
# [CV] min_samples_leaf=1, min_weight_fraction_leaf=0.0, n_estimators=100
# [CV]  min_samples_leaf=1, min_weight_fraction_leaf=0.0, n_estimators=100, score=0.880, total=   2.7s
# [CV] min_samples_leaf=1, min_weight_fraction_leaf=0.0, n_estimators=1
# [CV]  min_samples_leaf=1, min_weight_fraction_leaf=0.0, n_estimators=1, score=0.803, total=   0.0s
# [CV] min_samples_leaf=1, min_weight_fraction_leaf=0.0, n_estimators=1
# [CV]  min_samples_leaf=1, min_weight_fraction_leaf=0.0, n_estimators=1, score=0.785, total=   0.0s
# [CV] min_samples_leaf=1, min_weight_fraction_leaf=0.0, n_estimators=1
# [CV]  min_samples_leaf=1, min_weight_fraction_leaf=0.0, n_estimators=1, score=0.785, total=   0.0s
# [CV] min_samples_leaf=1, min_weight_fraction_leaf=0.0, n_estimators=400
# [CV]  min_samples_leaf=1, min_weight_fraction_leaf=0.0, n_estimators=400, score=0.907, total=  10.9s
# [CV] min_samples_leaf=1, min_weight_fraction_leaf=0.0, n_estimators=400
# [CV]  min_samples_leaf=1, min_weight_fraction_leaf=0.0, n_estimators=400, score=0.887, total=  10.5s
# [CV] min_samples_leaf=1, min_weight_fraction_leaf=0.0, n_estimators=400
# [CV]  min_samples_leaf=1, min_weight_fraction_leaf=0.0, n_estimators=400, score=0.880, total=  11.2s
# [CV] min_samples_leaf=1, min_weight_fraction_leaf=0.01, n_estimators=200
# [CV]  min_samples_leaf=1, min_weight_fraction_leaf=0.01, n_estimators=200, score=0.883, total=   4.6s
# [CV] min_samples_leaf=1, min_weight_fraction_leaf=0.01, n_estimators=200
# [CV]  min_samples_leaf=1, min_weight_fraction_leaf=0.01, n_estimators=200, score=0.875, total=   4.3s
# [CV] min_samples_leaf=1, min_weight_fraction_leaf=0.01, n_estimators=200
# [CV]  min_samples_leaf=1, min_weight_fraction_leaf=0.01, n_estimators=200, score=0.864, total=   3.8s
# [CV] min_samples_leaf=1, min_weight_fraction_leaf=0.01, n_estimators=100
# [CV]  min_samples_leaf=1, min_weight_fraction_leaf=0.01, n_estimators=100, score=0.882, total=   2.1s
# [CV] min_samples_leaf=1, min_weight_fraction_leaf=0.01, n_estimators=100
# [CV]  min_samples_leaf=1, min_weight_fraction_leaf=0.01, n_estimators=100, score=0.873, total=   2.1s
# [CV] min_samples_leaf=1, min_weight_fraction_leaf=0.01, n_estimators=100
# [CV]  min_samples_leaf=1, min_weight_fraction_leaf=0.01, n_estimators=100, score=0.864, total=   2.1s
# [CV] min_samples_leaf=1, min_weight_fraction_leaf=0.01, n_estimators=1
# [CV]  min_samples_leaf=1, min_weight_fraction_leaf=0.01, n_estimators=1, score=0.823, total=   0.1s
# [CV] min_samples_leaf=1, min_weight_fraction_leaf=0.01, n_estimators=1
# [CV]  min_samples_leaf=1, min_weight_fraction_leaf=0.01, n_estimators=1, score=0.793, total=   0.0s
# [CV] min_samples_leaf=1, min_weight_fraction_leaf=0.01, n_estimators=1
# [CV]  min_samples_leaf=1, min_weight_fraction_leaf=0.01, n_estimators=1, score=0.806, total=   0.0s
# [CV] min_samples_leaf=1, min_weight_fraction_leaf=0.01, n_estimators=400
# [CV]  min_samples_leaf=1, min_weight_fraction_leaf=0.01, n_estimators=400, score=0.881, total=   7.6s
# [CV] min_samples_leaf=1, min_weight_fraction_leaf=0.01, n_estimators=400
# [CV]  min_samples_leaf=1, min_weight_fraction_leaf=0.01, n_estimators=400, score=0.878, total=   7.4s
# [CV] min_samples_leaf=1, min_weight_fraction_leaf=0.01, n_estimators=400
# [CV]  min_samples_leaf=1, min_weight_fraction_leaf=0.01, n_estimators=400, score=0.859, total=   7.3s
# [CV] min_samples_leaf=3, min_weight_fraction_leaf=0.0, n_estimators=200
# [CV]  min_samples_leaf=3, min_weight_fraction_leaf=0.0, n_estimators=200, score=0.900, total=   5.4s
# [CV] min_samples_leaf=3, min_weight_fraction_leaf=0.0, n_estimators=200
# [CV]  min_samples_leaf=3, min_weight_fraction_leaf=0.0, n_estimators=200, score=0.885, total=   5.3s
# [CV] min_samples_leaf=3, min_weight_fraction_leaf=0.0, n_estimators=200
# [CV]  min_samples_leaf=3, min_weight_fraction_leaf=0.0, n_estimators=200, score=0.884, total=   4.9s
# [CV] min_samples_leaf=3, min_weight_fraction_leaf=0.0, n_estimators=100
# [CV]  min_samples_leaf=3, min_weight_fraction_leaf=0.0, n_estimators=100, score=0.902, total=   2.6s
# [CV] min_samples_leaf=3, min_weight_fraction_leaf=0.0, n_estimators=100
# [CV]  min_samples_leaf=3, min_weight_fraction_leaf=0.0, n_estimators=100, score=0.886, total=   2.6s
# [CV] min_samples_leaf=3, min_weight_fraction_leaf=0.0, n_estimators=100
# [CV]  min_samples_leaf=3, min_weight_fraction_leaf=0.0, n_estimators=100, score=0.885, total=   2.5s
# [CV] min_samples_leaf=3, min_weight_fraction_leaf=0.0, n_estimators=1
# [CV]  min_samples_leaf=3, min_weight_fraction_leaf=0.0, n_estimators=1, score=0.791, total=   0.0s
# [CV] min_samples_leaf=3, min_weight_fraction_leaf=0.0, n_estimators=1
# [CV]  min_samples_leaf=3, min_weight_fraction_leaf=0.0, n_estimators=1, score=0.760, total=   0.1s
# [CV] min_samples_leaf=3, min_weight_fraction_leaf=0.0, n_estimators=1
# [CV]  min_samples_leaf=3, min_weight_fraction_leaf=0.0, n_estimators=1, score=0.774, total=   0.0s
# [CV] min_samples_leaf=3, min_weight_fraction_leaf=0.0, n_estimators=400
# [CV]  min_samples_leaf=3, min_weight_fraction_leaf=0.0, n_estimators=400, score=0.902, total=   9.9s
# [CV] min_samples_leaf=3, min_weight_fraction_leaf=0.0, n_estimators=400
# [CV]  min_samples_leaf=3, min_weight_fraction_leaf=0.0, n_estimators=400, score=0.889, total=   9.9s
# [CV] min_samples_leaf=3, min_weight_fraction_leaf=0.0, n_estimators=400
# [CV]  min_samples_leaf=3, min_weight_fraction_leaf=0.0, n_estimators=400, score=0.880, total=   9.2s
# [CV] min_samples_leaf=3, min_weight_fraction_leaf=0.01, n_estimators=200
# [CV]  min_samples_leaf=3, min_weight_fraction_leaf=0.01, n_estimators=200, score=0.882, total=   4.0s
# [CV] min_samples_leaf=3, min_weight_fraction_leaf=0.01, n_estimators=200
# [CV]  min_samples_leaf=3, min_weight_fraction_leaf=0.01, n_estimators=200, score=0.880, total=   3.4s
# [CV] min_samples_leaf=3, min_weight_fraction_leaf=0.01, n_estimators=200
# [CV]  min_samples_leaf=3, min_weight_fraction_leaf=0.01, n_estimators=200, score=0.860, total=   4.0s
# [CV] min_samples_leaf=3, min_weight_fraction_leaf=0.01, n_estimators=100
# [CV]  min_samples_leaf=3, min_weight_fraction_leaf=0.01, n_estimators=100, score=0.882, total=   2.1s
# [CV] min_samples_leaf=3, min_weight_fraction_leaf=0.01, n_estimators=100
# [CV]  min_samples_leaf=3, min_weight_fraction_leaf=0.01, n_estimators=100, score=0.875, total=   2.0s
# [CV] min_samples_leaf=3, min_weight_fraction_leaf=0.01, n_estimators=100
# [CV]  min_samples_leaf=3, min_weight_fraction_leaf=0.01, n_estimators=100, score=0.861, total=   2.0s
# [CV] min_samples_leaf=3, min_weight_fraction_leaf=0.01, n_estimators=1
# [CV]  min_samples_leaf=3, min_weight_fraction_leaf=0.01, n_estimators=1, score=0.770, total=   0.0s
# [CV] min_samples_leaf=3, min_weight_fraction_leaf=0.01, n_estimators=1
# [CV]  min_samples_leaf=3, min_weight_fraction_leaf=0.01, n_estimators=1, score=0.818, total=   0.0s
# [CV] min_samples_leaf=3, min_weight_fraction_leaf=0.01, n_estimators=1
# [CV]  min_samples_leaf=3, min_weight_fraction_leaf=0.01, n_estimators=1, score=0.815, total=   0.0s
# [CV] min_samples_leaf=3, min_weight_fraction_leaf=0.01, n_estimators=400
# [CV]  min_samples_leaf=3, min_weight_fraction_leaf=0.01, n_estimators=400, score=0.882, total=   7.0s
# [CV] min_samples_leaf=3, min_weight_fraction_leaf=0.01, n_estimators=400
# [CV]  min_samples_leaf=3, min_weight_fraction_leaf=0.01, n_estimators=400, score=0.874, total=   8.5s
# [CV] min_samples_leaf=3, min_weight_fraction_leaf=0.01, n_estimators=400
# [CV]  min_samples_leaf=3, min_weight_fraction_leaf=0.01, n_estimators=400, score=0.859, total=   8.3s
# [CV] min_samples_leaf=5, min_weight_fraction_leaf=0.0, n_estimators=200
# [CV]  min_samples_leaf=5, min_weight_fraction_leaf=0.0, n_estimators=200, score=0.901, total=   5.0s
# [CV] min_samples_leaf=5, min_weight_fraction_leaf=0.0, n_estimators=200
# [CV]  min_samples_leaf=5, min_weight_fraction_leaf=0.0, n_estimators=200, score=0.886, total=   4.9s
# [CV] min_samples_leaf=5, min_weight_fraction_leaf=0.0, n_estimators=200
# [CV]  min_samples_leaf=5, min_weight_fraction_leaf=0.0, n_estimators=200, score=0.875, total=   5.2s
# [CV] min_samples_leaf=5, min_weight_fraction_leaf=0.0, n_estimators=100
# [CV]  min_samples_leaf=5, min_weight_fraction_leaf=0.0, n_estimators=100, score=0.901, total=   2.4s
# [CV] min_samples_leaf=5, min_weight_fraction_leaf=0.0, n_estimators=100
# [CV]  min_samples_leaf=5, min_weight_fraction_leaf=0.0, n_estimators=100, score=0.886, total=   2.2s
# [CV] min_samples_leaf=5, min_weight_fraction_leaf=0.0, n_estimators=100
# [CV]  min_samples_leaf=5, min_weight_fraction_leaf=0.0, n_estimators=100, score=0.876, total=   2.2s
# [CV] min_samples_leaf=5, min_weight_fraction_leaf=0.0, n_estimators=1
# [CV]  min_samples_leaf=5, min_weight_fraction_leaf=0.0, n_estimators=1, score=0.793, total=   0.0s
# [CV] min_samples_leaf=5, min_weight_fraction_leaf=0.0, n_estimators=1
# [CV]  min_samples_leaf=5, min_weight_fraction_leaf=0.0, n_estimators=1, score=0.781, total=   0.0s
# [CV] min_samples_leaf=5, min_weight_fraction_leaf=0.0, n_estimators=1
# [CV]  min_samples_leaf=5, min_weight_fraction_leaf=0.0, n_estimators=1, score=0.737, total=   0.0s
# [CV] min_samples_leaf=5, min_weight_fraction_leaf=0.0, n_estimators=400
# [CV]  min_samples_leaf=5, min_weight_fraction_leaf=0.0, n_estimators=400, score=0.897, total=  10.6s
# [CV] min_samples_leaf=5, min_weight_fraction_leaf=0.0, n_estimators=400
# [CV]  min_samples_leaf=5, min_weight_fraction_leaf=0.0, n_estimators=400, score=0.888, total=   8.5s
# [CV] min_samples_leaf=5, min_weight_fraction_leaf=0.0, n_estimators=400
# [CV]  min_samples_leaf=5, min_weight_fraction_leaf=0.0, n_estimators=400, score=0.880, total=   9.6s
# [CV] min_samples_leaf=5, min_weight_fraction_leaf=0.01, n_estimators=200
# [CV]  min_samples_leaf=5, min_weight_fraction_leaf=0.01, n_estimators=200, score=0.887, total=   4.1s
# [CV] min_samples_leaf=5, min_weight_fraction_leaf=0.01, n_estimators=200
# [CV]  min_samples_leaf=5, min_weight_fraction_leaf=0.01, n_estimators=200, score=0.877, total=   3.9s
# [CV] min_samples_leaf=5, min_weight_fraction_leaf=0.01, n_estimators=200
# [CV]  min_samples_leaf=5, min_weight_fraction_leaf=0.01, n_estimators=200, score=0.862, total=   4.0s
# [CV] min_samples_leaf=5, min_weight_fraction_leaf=0.01, n_estimators=100
# [CV]  min_samples_leaf=5, min_weight_fraction_leaf=0.01, n_estimators=100, score=0.885, total=   1.9s
# [CV] min_samples_leaf=5, min_weight_fraction_leaf=0.01, n_estimators=100
# [CV]  min_samples_leaf=5, min_weight_fraction_leaf=0.01, n_estimators=100, score=0.877, total=   1.9s
# [CV] min_samples_leaf=5, min_weight_fraction_leaf=0.01, n_estimators=100
# [CV]  min_samples_leaf=5, min_weight_fraction_leaf=0.01, n_estimators=100, score=0.860, total=   2.0s
# [CV] min_samples_leaf=5, min_weight_fraction_leaf=0.01, n_estimators=1
# [CV]  min_samples_leaf=5, min_weight_fraction_leaf=0.01, n_estimators=1, score=0.775, total=   0.0s
# [CV] min_samples_leaf=5, min_weight_fraction_leaf=0.01, n_estimators=1
# [CV]  min_samples_leaf=5, min_weight_fraction_leaf=0.01, n_estimators=1, score=0.774, total=   0.0s
# [CV] min_samples_leaf=5, min_weight_fraction_leaf=0.01, n_estimators=1
# [CV]  min_samples_leaf=5, min_weight_fraction_leaf=0.01, n_estimators=1, score=0.784, total=   0.0s
# [CV] min_samples_leaf=5, min_weight_fraction_leaf=0.01, n_estimators=400
# [CV]  min_samples_leaf=5, min_weight_fraction_leaf=0.01, n_estimators=400, score=0.882, total=   8.1s
# [CV] min_samples_leaf=5, min_weight_fraction_leaf=0.01, n_estimators=400
# [CV]  min_samples_leaf=5, min_weight_fraction_leaf=0.01, n_estimators=400, score=0.879, total=   7.8s
# [CV] min_samples_leaf=5, min_weight_fraction_leaf=0.01, n_estimators=400
# [CV]  min_samples_leaf=5, min_weight_fraction_leaf=0.01, n_estimators=400, score=0.860, total=   8.0s
# [CV] min_samples_leaf=7, min_weight_fraction_leaf=0.0, n_estimators=200
# [CV]  min_samples_leaf=7, min_weight_fraction_leaf=0.0, n_estimators=200, score=0.897, total=   5.1s
# [CV] min_samples_leaf=7, min_weight_fraction_leaf=0.0, n_estimators=200
# [CV]  min_samples_leaf=7, min_weight_fraction_leaf=0.0, n_estimators=200, score=0.886, total=   4.6s
# [CV] min_samples_leaf=7, min_weight_fraction_leaf=0.0, n_estimators=200
# [CV]  min_samples_leaf=7, min_weight_fraction_leaf=0.0, n_estimators=200, score=0.875, total=   4.5s
# [CV] min_samples_leaf=7, min_weight_fraction_leaf=0.0, n_estimators=100
# [CV]  min_samples_leaf=7, min_weight_fraction_leaf=0.0, n_estimators=100, score=0.895, total=   2.3s
# [CV] min_samples_leaf=7, min_weight_fraction_leaf=0.0, n_estimators=100
# [CV]  min_samples_leaf=7, min_weight_fraction_leaf=0.0, n_estimators=100, score=0.886, total=   2.3s
# [CV] min_samples_leaf=7, min_weight_fraction_leaf=0.0, n_estimators=100
# [CV]  min_samples_leaf=7, min_weight_fraction_leaf=0.0, n_estimators=100, score=0.877, total=   2.3s
# [CV] min_samples_leaf=7, min_weight_fraction_leaf=0.0, n_estimators=1
# [CV]  min_samples_leaf=7, min_weight_fraction_leaf=0.0, n_estimators=1, score=0.788, total=   0.0s
# [CV] min_samples_leaf=7, min_weight_fraction_leaf=0.0, n_estimators=1
# [CV]  min_samples_leaf=7, min_weight_fraction_leaf=0.0, n_estimators=1, score=0.781, total=   0.0s
# [CV] min_samples_leaf=7, min_weight_fraction_leaf=0.0, n_estimators=1
# [CV]  min_samples_leaf=7, min_weight_fraction_leaf=0.0, n_estimators=1, score=0.786, total=   0.0s
# [CV] min_samples_leaf=7, min_weight_fraction_leaf=0.0, n_estimators=400
# [CV]  min_samples_leaf=7, min_weight_fraction_leaf=0.0, n_estimators=400, score=0.896, total=   9.4s
# [CV] min_samples_leaf=7, min_weight_fraction_leaf=0.0, n_estimators=400
# [CV]  min_samples_leaf=7, min_weight_fraction_leaf=0.0, n_estimators=400, score=0.890, total=   9.5s
# [CV] min_samples_leaf=7, min_weight_fraction_leaf=0.0, n_estimators=400
# [CV]  min_samples_leaf=7, min_weight_fraction_leaf=0.0, n_estimators=400, score=0.873, total=   9.2s
# [CV] min_samples_leaf=7, min_weight_fraction_leaf=0.01, n_estimators=200
# [CV]  min_samples_leaf=7, min_weight_fraction_leaf=0.01, n_estimators=200, score=0.883, total=   3.9s
# [CV] min_samples_leaf=7, min_weight_fraction_leaf=0.01, n_estimators=200
# [CV]  min_samples_leaf=7, min_weight_fraction_leaf=0.01, n_estimators=200, score=0.875, total=   3.8s
# [CV] min_samples_leaf=7, min_weight_fraction_leaf=0.01, n_estimators=200
# [CV]  min_samples_leaf=7, min_weight_fraction_leaf=0.01, n_estimators=200, score=0.861, total=   3.9s
# [CV] min_samples_leaf=7, min_weight_fraction_leaf=0.01, n_estimators=100
# [CV]  min_samples_leaf=7, min_weight_fraction_leaf=0.01, n_estimators=100, score=0.884, total=   1.9s
# [CV] min_samples_leaf=7, min_weight_fraction_leaf=0.01, n_estimators=100
# [CV]  min_samples_leaf=7, min_weight_fraction_leaf=0.01, n_estimators=100, score=0.872, total=   2.0s
# [CV] min_samples_leaf=7, min_weight_fraction_leaf=0.01, n_estimators=100
# [CV]  min_samples_leaf=7, min_weight_fraction_leaf=0.01, n_estimators=100, score=0.861, total=   2.0s
# [CV] min_samples_leaf=7, min_weight_fraction_leaf=0.01, n_estimators=1
# [CV]  min_samples_leaf=7, min_weight_fraction_leaf=0.01, n_estimators=1, score=0.853, total=   0.0s
# [CV] min_samples_leaf=7, min_weight_fraction_leaf=0.01, n_estimators=1
# [CV]  min_samples_leaf=7, min_weight_fraction_leaf=0.01, n_estimators=1, score=0.761, total=   0.0s
# [CV] min_samples_leaf=7, min_weight_fraction_leaf=0.01, n_estimators=1
# [CV]  min_samples_leaf=7, min_weight_fraction_leaf=0.01, n_estimators=1, score=0.766, total=   0.0s
# [CV] min_samples_leaf=7, min_weight_fraction_leaf=0.01, n_estimators=400
# [CV]  min_samples_leaf=7, min_weight_fraction_leaf=0.01, n_estimators=400, score=0.883, total=   7.7s
# [CV] min_samples_leaf=7, min_weight_fraction_leaf=0.01, n_estimators=400
# [CV]  min_samples_leaf=7, min_weight_fraction_leaf=0.01, n_estimators=400, score=0.875, total=   8.0s
# [CV] min_samples_leaf=7, min_weight_fraction_leaf=0.01, n_estimators=400
# [CV]  min_samples_leaf=7, min_weight_fraction_leaf=0.01, n_estimators=400, score=0.860, total=   7.5s
# [Parallel(n_jobs=1)]: Done  96 out of  96 | elapsed:  6.3min finished
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=RandomForestClassifier(bootstrap=True, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=200, n_jobs=None,
#                                               oob_score=False,
#                                               random_state=None, verbose=0,
#                                               warm_start=False),
#              iid='warn', n_jobs=None,
#              param_grid={'min_samples_leaf': [1, 3, 5, 7],
#                          'min_weight_fraction_leaf': [0.0, 0.01],
#                          'n_estimators': [200, 100, 1, 400]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 200}
# 0.8920465382414648

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'model_2.sav'
joblib.dump(model, filename)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-d7f9b77d1840> in <module>
#       5 import joblib
#       6 filename = 'model_2.sav'
# ----> 7 joblib.dump(model, filename)
#
# NameError: name 'model' is not defined
